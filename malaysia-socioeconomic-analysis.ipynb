# %% [markdown]
# # Step 1 : Import Library and Dataset

# %%
import pandas as pd
df1 = pd.read_csv("C:/Users/MUHAMAD NAIM BIN ZOL/Data Science Project/malaysia-socioeconomic-analysis/hies_district.csv")
df1
# Out:
#            date              state           district  income_mean  \
# 0    2022-01-01              Johor         Batu Pahat         7419
# 1    2022-01-01              Johor        Johor Bahru         9869
# 2    2022-01-01              Johor             Kluang         6461
# 3    2022-01-01              Johor        Kota Tinggi         7529
# 4    2022-01-01              Johor            Mersing         5426
# ..          ...                ...                ...          ...
# 155  2022-01-01            Sarawak             Beluru         4873
# 156  2022-01-01            Sarawak        Telang Usan         4692
# 157  2022-01-01  W.P. Kuala Lumpur  W.P. Kuala Lumpur        13325
# 158  2022-01-01        W.P. Labuan        W.P. Labuan         8250
# 159  2022-01-01     W.P. Putrajaya     W.P. Putrajaya        13473
#
#      income_median  expenditure_mean     gini  poverty
# 0             6347              4570  0.33830      5.1
# ...

# %%
df1.head(20)
# Out:
#           date  state       district  income_mean  income_median  \
# 0   2022-01-01  Johor     Batu Pahat         7419           6347
# 1   2022-01-01  Johor    Johor Bahru         9869           8232
# 2   2022-01-01  Johor         Kluang         6461           5204
# 3   2022-01-01  Johor    Kota Tinggi         7529           6227
# 4   2022-01-01  Johor        Mersing         5426           4445
# 5   2022-01-01  Johor           Muar         7572           5724
# 6   2022-01-01  Johor        Pontian         6913           5616
# 7   2022-01-01  Johor        Segamat         6578           5318
# 8   2022-01-01  Johor          Kulai         9177           7460
# 9   2022-01-01  Johor        Tangkak         7093           5622
# 10  2022-01-01  Kedah         Baling         4263           3400
# 11  2022-01-01  Kedah  Bandar Baharu         4565           3922
# 12  2022-01-01  Kedah     Kota Setar         5959           4751
# ...

# %%
df1.shape
# Out:
# (160, 8)

# %% [markdown]
# # Step 2 : Data Cleaning

# %% [markdown]
# Drop unnecessary columns from the DataFrame.

# %%
df1.head()
# Out:
#          date  state     district  income_mean  income_median  \
# 0  2022-01-01  Johor   Batu Pahat         7419           6347
# 1  2022-01-01  Johor  Johor Bahru         9869           8232
# 2  2022-01-01  Johor       Kluang         6461           5204
# 3  2022-01-01  Johor  Kota Tinggi         7529           6227
# 4  2022-01-01  Johor      Mersing         5426           4445
#
#    expenditure_mean     gini  poverty
# 0              4570  0.33830      5.1
# 1              6139  0.35850      3.7
# 2              4399  0.35367      7.2
# 3              4498  0.34335      5.0
# 4              4032  0.33877     12.7

# %%
df1.groupby('date')['date'].agg('count')
# Out:
# date
# 2022-01-01    160
# Name: date, dtype: int64

# %%
df2 = df1.drop(['date'],axis='columns')
df2.head(20)
# Out:
#     state       district  income_mean  income_median  expenditure_mean  \
# 0   Johor     Batu Pahat         7419           6347              4570
# 1   Johor    Johor Bahru         9869           8232              6139
# 2   Johor         Kluang         6461           5204              4399
# 3   Johor    Kota Tinggi         7529           6227              4498
# 4   Johor        Mersing         5426           4445              4032
# 5   Johor           Muar         7572           5724              4740
# 6   Johor        Pontian         6913           5616              4535
# 7   Johor        Segamat         6578           5318              4426
# 8   Johor          Kulai         9177           7460              5646
# 9   Johor        Tangkak         7093           5622              4198
# 10  Kedah         Baling         4263           3400              2732
# 11  Kedah  Bandar Baharu         4565           3922              2751
# ...

# %%
df2.isnull().sum()
# Out:
# state               0
# district            0
# income_mean         0
# income_median       0
# expenditure_mean    0
# gini                0
# poverty             0
# dtype: int64

# %%
df2.shape
# Out:
# (160, 7)

# %% [markdown]
# # Step 3: Data Visualization

# %% [markdown]
# 1. Income and Expenditure Analysis:
#
# * Mean and Median Income by District and State.
# * Mean Expenditure by District and State.

# %%
df2_grouped_income_mean_bystate = df2.groupby('state', as_index=False)['income_mean'].mean()
df2_grouped_income_mean_bystate
# Out:
#                 state   income_mean
# 0               Johor   7403.700000
# 1               Kedah   5281.916667
# 2            Kelantan   4443.818182
# 3              Melaka   7657.666667
# 4     Negeri Sembilan   5485.285714
# 5              Pahang   5306.636364
# 6               Perak   5424.153846
# 7              Perlis   5664.000000
# 8        Pulau Pinang   8167.800000
# 9               Sabah   5368.629630
# 10            Sarawak   4925.400000
# 11           Selangor  11087.444444
# 12         Terengganu   6983.500000
# 13  W.P. Kuala Lumpur  13325.000000
# 14        W.P. Labuan   8250.000000
# 15     W.P. Putrajaya  13473.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

# Plot Mean Income by State

plt.figure(figsize=(14, 7))
sns.barplot(x='income_mean', y='state', data=df2, ci=None, palette="viridis")
plt.title('Mean Income by State')
plt.xlabel('Mean Income')
plt.ylabel('State')
plt.show()
# Out:
# C:\Users\MUHAMAD NAIM BIN ZOL\AppData\Local\Temp\ipykernel_30064\1255922746.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='income_mean', y='state', data=df2, ci=None, palette="viridis")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

# Plot Mean Income by State

plt.figure(figsize=(14, 7))
sns.barplot(x='income_mean', y='state', data=df2_grouped_income_mean_bystate, ci=None, palette="viridis")
plt.title('Mean Income by State')
plt.xlabel('Mean Income')
plt.ylabel('State')
plt.show()
# Out:
# C:\Users\MUHAMAD NAIM BIN ZOL\AppData\Local\Temp\ipykernel_30064\187263757.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='income_mean', y='state', data=df2_grouped_income_mean_bystate, ci=None, palette="viridis")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Group by state and calculate the mean income
df_grouped = df2.groupby('state', as_index=False)['income_mean'].mean()

# Sort the grouped DataFrame by 'income_mean' in descending order
df_sorted = df_grouped.sort_values(by='income_mean', ascending=False)

# Plot Mean Income by State in descending order
plt.figure(figsize=(14, 7))
sns.barplot(x='income_mean', y='state', data=df_sorted, ci=None, palette="viridis")
plt.title('Mean Income by State')
plt.xlabel('Mean Income')
plt.ylabel('State')
plt.show()
# Out:
# C:\Users\MUHAMAD NAIM BIN ZOL\AppData\Local\Temp\ipykernel_30064\877266628.py:13: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='income_mean', y='state', data=df_sorted, ci=None, palette="viridis")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Group by state and calculate the mean income
df_grouped = df2.groupby('state', as_index=False)['income_mean'].mean()

# Sort the grouped DataFrame by 'income_mean' in descending order
df_sorted = df_grouped.sort_values(by='income_mean', ascending=False)

# Create a blue gradient palette
blue_gradient = sns.color_palette("Blues", n_colors=len(df_sorted))

# Plot Mean Income by State in descending order with a blue gradient
plt.figure(figsize=(14, 7))
sns.barplot(x='income_mean', y='state', data=df_sorted, ci=None, palette=blue_gradient)
plt.title('Mean Income by State')
plt.xlabel('Mean Income')
plt.ylabel('State')
plt.show()
# Out:
# C:\Users\MUHAMAD NAIM BIN ZOL\AppData\Local\Temp\ipykernel_30064\194725924.py:16: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='income_mean', y='state', data=df_sorted, ci=None, palette=blue_gradient)

# %%
df2_grouped_income_median_bystate = df2.groupby('state', as_index=False)['income_median'].mean()
df2_grouped_income_median_bystate
# Out:
#                 state  income_median
# 0               Johor    6019.500000
# 1               Kedah    4281.333333
# 2            Kelantan    3338.727273
# 3              Melaka    6021.000000
# 4     Negeri Sembilan    4399.000000
# 5              Pahang    4434.363636
# 6               Perak    4254.153846
# 7              Perlis    4713.000000
# 8        Pulau Pinang    6503.000000
# 9               Sabah    4121.222222
# 10            Sarawak    3982.625000
# 11           Selangor    9196.333333
# 12         Terengganu    5723.500000
# 13  W.P. Kuala Lumpur   10234.000000
# 14        W.P. Labuan    6904.000000
# 15     W.P. Putrajaya   10056.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Group by state and calculate the median income
df_grouped_median = df2.groupby('state', as_index=False)['income_median'].median()

# Sort the grouped DataFrame by 'income_median' in descending order
df_sorted_median = df_grouped_median.sort_values(by='income_median', ascending=False)

# Create a green gradient palette
green_gradient = sns.color_palette("Greens", n_colors=len(df_sorted_median))

# Plot Median Income by State in descending order with a green gradient
plt.figure(figsize=(14, 7))
sns.barplot(x='income_median', y='state', data=df_sorted_median, ci=None, palette=green_gradient)
plt.title('Median Income by State')
plt.xlabel('Median Income')
plt.ylabel('State')
plt.show()
# Out:
# C:\Users\MUHAMAD NAIM BIN ZOL\AppData\Local\Temp\ipykernel_30064\56119708.py:16: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='income_median', y='state', data=df_sorted_median, ci=None, palette=green_gradient)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Group by state and calculate the mean and median income
df_grouped = df2.groupby('state', as_index=False).agg({'income_mean': 'mean', 'income_median': 'median'})

# Sort the grouped DataFrame by mean income in descending order
df_sorted = df_grouped.sort_values(by='income_mean', ascending=False)

# Melt the DataFrame for easier plotting
df_melted = df_sorted.melt(id_vars='state', value_vars=['income_mean', 'income_median'], 
                           var_name='Income Type', value_name='Income')

# Create custom color palettes for mean and median income
mean_palette = sns.color_palette("Blues", n_colors=len(df_sorted))
median_palette = sns.color_palette("Greens", n_colors=len(df_sorted))

# Assign the colors to the melted DataFrame
df_melted['Color'] = df_melted['Income Type'].apply(lambda x: mean_palette if x == 'income_mean' else median_palette)

# Plot Mean and Median Income by State in descending order
plt.figure(figsize=(14, 7))
for i, state in enumerate(df_sorted['state']):
    state_data = df_melted[df_melted['state'] == state]
    plt.barh(state, state_data[state_data['Income Type'] == 'income_mean']['Income'].values[0], color=mean_palette[i])
    plt.barh(state, state_data[state_data['Income Type'] == 'income_median']['Income'].values[0], color=median_palette[i])

plt.title('Mean and Median Income by State')
plt.xlabel('Income')
plt.ylabel('State')
plt.legend(['Mean Income', 'Median Income'])
plt.show()

# %% [markdown]
# The reason mean income and median income need to be compared are:
#
# 1. Skewness and Distribution: The mean is affected by very high or low values, but the median is not, so the median is better for uneven data.
#
# 2. Income Equality: High incomes can make the mean misleading, while the median shows what a typical person earns.
#
# 3. Policy Making: The median is more useful for understanding how most people live and for creating effective economic policies.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Group by state and calculate the expenditure mean
df_grouped_expenditure_mean = df2.groupby('state', as_index=False)['expenditure_mean'].mean()

# Sort the grouped DataFrame by 'expenditure_mean' in descending order
df_sorted_expenditure_mean = df_grouped_expenditure_mean.sort_values(by='expenditure_mean', ascending=False)

# Create a brighter yellow gradient palette
bright_yellow_gradient = sns.color_palette("YlOrBr", n_colors=len(df_sorted_expenditure_mean))

# Plot Expenditure Mean by State in descending order with a bright yellow gradient
plt.figure(figsize=(14, 7))
sns.barplot(x='expenditure_mean', y='state', data=df_sorted_expenditure_mean, ci=None, palette=bright_yellow_gradient)
plt.title('Expenditure Mean by State')
plt.xlabel('Expenditure Mean')
plt.ylabel('State')
plt.show()
# Out:
# C:\Users\MUHAMAD NAIM BIN ZOL\AppData\Local\Temp\ipykernel_30064\1821080388.py:16: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='expenditure_mean', y='state', data=df_sorted_expenditure_mean, ci=None, palette=bright_yellow_gradient)

# %% [markdown]
# 2. Inequality and Poverty Analysis:
#
# * Gini Coefficient by District and State.
# * Poverty Rate by District and State.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Sort DataFrame by Gini coefficient descending
df2_sorted_gini = df2.sort_values(by='gini', ascending=False)

# Plot Gini Coefficient by State
plt.figure(figsize=(14, 7))
sns.barplot(x='gini', y='state', data=df2_sorted_gini, ci=None, palette="magma")
plt.title('Gini Coefficient by State (Descending Order)')
plt.xlabel('Gini Coefficient')
plt.ylabel('State')
plt.show()

# Sort DataFrame by Poverty rate descending
df2_sorted_poverty = df2.sort_values(by='poverty', ascending=False)

# Plot Poverty Rate by State
plt.figure(figsize=(14, 7))
sns.barplot(x='poverty', y='state', data=df2_sorted_poverty, ci=None, palette="magma")
plt.title('Poverty Rate by State (Descending Order)')
plt.xlabel('Poverty Rate (%)')
plt.ylabel('State')
plt.show()
# Out:
# C:\Users\MUHAMAD NAIM BIN ZOL\AppData\Local\Temp\ipykernel_30064\3260010656.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='gini', y='state', data=df2_sorted_gini, ci=None, palette="magma")
# C:\Users\MUHAMAD NAIM BIN ZOL\AppData\Local\Temp\ipykernel_30064\3260010656.py:20: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='poverty', y='state', data=df2_sorted_poverty, ci=None, palette="magma")
